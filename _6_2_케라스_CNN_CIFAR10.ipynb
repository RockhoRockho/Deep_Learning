# %% [markdown]
# <a href="https://colab.research.google.com/github/RockhoRockho/Deep_Learning_Tensorflow/blob/main/_6_2_%EC%BC%80%EB%9D%BC%EC%8A%A4_CNN_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 케라스 CNN CIFAR 10
#
# - 50,000개의 학습데이터, 10,000개의 테스트 데이터로 구성
#
# - 데이터 복잡도가 MNIST보다 훨씬 높은 특징이 있음
#   - 신경망이 특징을 검출하기 어려움
#
#   <img src="https://www.researchgate.net/profile/Jean_Elsner/publication/329969195/figure/fig1/AS:708799606317059@1546002403551/Images-from-the-CIFAR-10-13-dataset-and-their-corresponding-classes-CIFAR-10.ppm">

# %% [markdown]
# ### modules import

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

import numpy as np

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

print(x_train_full.shape, y_train_full.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# 170508288/170498071 [==============================] - 13s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
print(y_test[5])
# Out:
# [6]

# %%
np.random.seed(777)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'sheep', 'truck']

sample_size = 9
random_idx = np.random.randint(60000, size=sample_size)

plt.figure(figsize=(5, 5))
for i, idx in enumerate(random_idx):
  plt.subplot(3, 3, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train_full[i])
  plt.xlabel(class_names[int(y_train_full[i])])

plt.show()

# %%
x_mean = np.mean(x_train_full, axis=(0, 1, 2))
x_std = np.std(x_train_full, axis=(0, 1, 2))

x_train_full = (x_train_full - x_mean) / x_std
x_test = (x_test - x_mean) / x_std

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.3)

# %%
print(x_train.shape)
print(y_train.shape)

print(x_val.shape)
print(y_val.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (35000, 32, 32, 3)
# (35000, 1)
# (15000, 32, 32, 3)
# (15000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ### 모델 구성 및 컴파일

# %%
def model_build():
  model = Sequential()

  input = Input(shape=(32, 32, 3))

  output = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(input)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  
  output = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  
  output = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)

  output = Flatten()(output)
  output = Dense(256, activation='relu')(output)
  output = Dense(128, activation='relu')(output)
  output = Dense(10 , activation='softmax')(output)
  
  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer=Adam(learning_rate=1e-4),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = model_build()
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 256)               524544
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 651,978
# Trainable params: 651,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 및 평가
# - [런타임]에서 GPU 설정

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.8716 - accuracy: 0.3328 - val_loss: 1.6305 - val_accuracy: 0.4175
# Epoch 2/30
# 137/137 [==============================] - 1s 9ms/step - loss: 1.5039 - accuracy: 0.4608 - val_loss: 1.4385 - val_accuracy: 0.4859
# Epoch 3/30
# 137/137 [==============================] - 1s 8ms/step - loss: 1.3820 - accuracy: 0.5090 - val_loss: 1.3356 - val_accuracy: 0.5188
# Epoch 4/30
# 137/137 [==============================] - 1s 8ms/step - loss: 1.2969 - accuracy: 0.5432 - val_loss: 1.2755 - val_accuracy: 0.5437
# Epoch 5/30
# 137/137 [==============================] - 1s 8ms/step - loss: 1.2357 - accuracy: 0.5659 - val_loss: 1.2324 - val_accuracy: 0.5618
# Epoch 6/30
# 137/137 [==============================] - 1s 8ms/step - loss: 1.1922 - accuracy: 0.5840 - val_loss: 1.2020 - val_accuracy: 0.5785
# Epoch 7/30
# 137/137 [==============================] - 1s 8ms/step - loss: 1.1358 - accuracy: 0.6052 - val_loss: 1.1720 - val_accuracy: 0.5867
# Epoch 8/30
# 137/137 [==============================] - 1s 9ms/step - loss: 1.1014 - accuracy: 0.6171 - val_loss: 1.1497 - val_accuracy: 0.5917
# Epoch 9/30
# 137/137 [==============================] - 1s 9ms/step - loss: 1.0649 - accuracy: 0.6279 - val_loss: 1.1064 - val_accuracy: 0.6141
# Epoch 10/30
# 137/137 [==============================] - 1s 9ms/step - loss: 1.0326 - accuracy: 0.6389 - val_loss: 1.0808 - val_accuracy: 0.6203
# Epoch 11/30
# 137/137 [==============================] - 1s 8ms/step - loss: 0.9943 - accuracy: 0.6567 - val_loss: 1.0683 - val_accuracy: 0.6260
# Epoch 12/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.9686 - accuracy: 0.6639 - val_loss: 1.0422 - val_accuracy: 0.6329
# Epoch 13/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.9445 - accuracy: 0.6741 - val_loss: 1.0118 - val_accuracy: 0.6411
# Epoch 14/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.9211 - accuracy: 0.6810 - val_loss: 1.0045 - val_accuracy: 0.6479
# Epoch 15/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.8977 - accuracy: 0.6903 - val_loss: 0.9867 - val_accuracy: 0.6561
# Epoch 16/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.8798 - accuracy: 0.6950 - val_loss: 0.9811 - val_accuracy: 0.6531
# Epoch 17/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.8597 - accuracy: 0.7053 - val_loss: 0.9711 - val_accuracy: 0.6655
# Epoch 18/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.8364 - accuracy: 0.7141 - val_loss: 0.9773 - val_accuracy: 0.6549
# Epoch 19/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.8236 - accuracy: 0.7187 - val_loss: 0.9449 - val_accuracy: 0.6668
# Epoch 20/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.8120 - accuracy: 0.7218 - val_loss: 0.9227 - val_accuracy: 0.6777
# Epoch 21/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.7890 - accuracy: 0.7298 - val_loss: 0.9305 - val_accuracy: 0.6755
# Epoch 22/30
# 137/137 [==============================] - 1s 8ms/step - loss: 0.7772 - accuracy: 0.7335 - val_loss: 0.9404 - val_accuracy: 0.6709
# Epoch 23/30
# 137/137 [==============================] - 1s 8ms/step - loss: 0.7557 - accuracy: 0.7397 - val_loss: 0.9089 - val_accuracy: 0.6859
# Epoch 24/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.7381 - accuracy: 0.7480 - val_loss: 0.9249 - val_accuracy: 0.6775
# Epoch 25/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.7267 - accuracy: 0.7519 - val_loss: 0.9113 - val_accuracy: 0.6845
# Epoch 26/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.7137 - accuracy: 0.7565 - val_loss: 0.9170 - val_accuracy: 0.6833
# Epoch 27/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.7053 - accuracy: 0.7592 - val_loss: 0.8813 - val_accuracy: 0.6957
# Epoch 28/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.6833 - accuracy: 0.7683 - val_loss: 0.8945 - val_accuracy: 0.6917
# Epoch 29/30
# 137/137 [==============================] - 1s 9ms/step - loss: 0.6664 - accuracy: 0.7743 - val_loss: 0.8992 - val_accuracy: 0.6905
# Epoch 30/30
# 137/137 [==============================] - 1s 8ms/step - loss: 0.6539 - accuracy: 0.7759 - val_loss: 0.8908 - val_accuracy: 0.6944

# %% [markdown]
# ### 학습 과정 시각화

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r:', label='val loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r:', label='val accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# - 해당 모델은 성능이 좋지 않음
# - 규제화, 드롭아웃 등 과대적합을 방지하는 기술 필요

# %%
def model_build2():
  model = Sequential()

  input = Input(shape=(32, 32, 3))

  output = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(input)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  
  output = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  
  output = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  output = Dropout(0.5)(output)

  output = Flatten()(output)
  output = Dense(256, activation='relu')(output)
  output = Dropout(0.5)(output)
  output = Dense(128, activation='relu')(output)
  output = Dense(10 , activation='softmax')(output)
  
  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer=Adam(learning_rate=1e-4),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = model_build2()
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout (Dropout)           (None, 4, 4, 128)         0
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_9 (Dense)             (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 652,874
# Trainable params: 652,426
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 및 평가
# - [런타임]에서 GPU 설정

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 137/137 [==============================] - 2s 13ms/step - loss: 2.5455 - accuracy: 0.2075 - val_loss: 2.3611 - val_accuracy: 0.1709
# Epoch 2/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.9720 - accuracy: 0.2912 - val_loss: 2.0809 - val_accuracy: 0.2605
# Epoch 3/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.8071 - accuracy: 0.3454 - val_loss: 1.6471 - val_accuracy: 0.4038
# Epoch 4/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.6983 - accuracy: 0.3820 - val_loss: 1.5112 - val_accuracy: 0.4602
# Epoch 5/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.6175 - accuracy: 0.4065 - val_loss: 1.4437 - val_accuracy: 0.4885
# Epoch 6/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.5710 - accuracy: 0.4270 - val_loss: 1.4032 - val_accuracy: 0.5052
# Epoch 7/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.5087 - accuracy: 0.4503 - val_loss: 1.3582 - val_accuracy: 0.5225
# Epoch 8/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.4648 - accuracy: 0.4675 - val_loss: 1.3343 - val_accuracy: 0.5343
# Epoch 9/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.4283 - accuracy: 0.4790 - val_loss: 1.2939 - val_accuracy: 0.5443
# Epoch 10/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.3928 - accuracy: 0.4961 - val_loss: 1.2569 - val_accuracy: 0.5624
# Epoch 11/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.3575 - accuracy: 0.5048 - val_loss: 1.2294 - val_accuracy: 0.5759
# Epoch 12/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.3256 - accuracy: 0.5228 - val_loss: 1.2011 - val_accuracy: 0.5834
# Epoch 13/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.2952 - accuracy: 0.5329 - val_loss: 1.1736 - val_accuracy: 0.5973
# Epoch 14/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.2678 - accuracy: 0.5471 - val_loss: 1.1504 - val_accuracy: 0.6005
# Epoch 15/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.2387 - accuracy: 0.5513 - val_loss: 1.1150 - val_accuracy: 0.6165
# Epoch 16/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.2106 - accuracy: 0.5636 - val_loss: 1.0934 - val_accuracy: 0.6249
# Epoch 17/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.1878 - accuracy: 0.5727 - val_loss: 1.0785 - val_accuracy: 0.6345
# Epoch 18/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.1594 - accuracy: 0.5837 - val_loss: 1.0519 - val_accuracy: 0.6390
# Epoch 19/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.1371 - accuracy: 0.5941 - val_loss: 1.0415 - val_accuracy: 0.6450
# Epoch 20/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.1194 - accuracy: 0.6039 - val_loss: 1.0176 - val_accuracy: 0.6513
# Epoch 21/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.1014 - accuracy: 0.6061 - val_loss: 1.0083 - val_accuracy: 0.6568
# Epoch 22/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.0772 - accuracy: 0.6154 - val_loss: 0.9854 - val_accuracy: 0.6593
# Epoch 23/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.0594 - accuracy: 0.6237 - val_loss: 0.9722 - val_accuracy: 0.6640
# Epoch 24/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.0454 - accuracy: 0.6265 - val_loss: 0.9667 - val_accuracy: 0.6695
# Epoch 25/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.0201 - accuracy: 0.6347 - val_loss: 0.9462 - val_accuracy: 0.6734
# Epoch 26/30
# 137/137 [==============================] - 1s 10ms/step - loss: 1.0060 - accuracy: 0.6386 - val_loss: 0.9362 - val_accuracy: 0.6765
# Epoch 27/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.9976 - accuracy: 0.6456 - val_loss: 0.9311 - val_accuracy: 0.6733
# Epoch 28/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.9805 - accuracy: 0.6499 - val_loss: 0.9103 - val_accuracy: 0.6853
# Epoch 29/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.9688 - accuracy: 0.6545 - val_loss: 0.9067 - val_accuracy: 0.6871
# Epoch 30/30
# 137/137 [==============================] - 1s 10ms/step - loss: 0.9522 - accuracy: 0.6621 - val_loss: 0.8986 - val_accuracy: 0.6880

# %% [markdown]
# ### 학습 과정 시각화

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r:', label='val loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r:', label='val accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.show()
